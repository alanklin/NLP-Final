# %% [markdown]
# # This notebook is to merge all data sources into one file.
#
# Run this to have complete_data.csv on your computer. You must have synthetic_reformat.csv, as well as the train and two other external datasets from Kaggle. We will be merging all four together to use in model building and training.

# %%
from _Setup import *

# %%
syn_df = pd.read_csv(synth_reformat) # Reformatted synthetic data

train_df = pd.read_json(train_path) #  Original training data

external1 = pd.read_json(external1) # External data 1
external2 = pd.read_json(external2) # External data 2

# %%
train_df.head()
# Out:
#    document                                          full_text  \
# 0         7  Design Thinking for innovation reflexion-Avril...
# 1        10  Diego Estrada\n\nDesign Thinking Assignment\n\...
# 2        16  Reporting process\n\nby Gilberto Gamboa\n\nCha...
# 3        20  Design Thinking for Innovation\n\nSindy Samaca...
# 4        56  Assignment:  Visualization Reflection  Submitt...
#
#                                               tokens  \
# 0  [Design, Thinking, for, innovation, reflexion,...
# 1  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 2  [Reporting, process, \n\n, by, Gilberto, Gambo...
# 3  [Design, Thinking, for, Innovation, \n\n, Sind...
# 4  [Assignment, :,   , Visualization,  , Reflecti...
#
#                                  trailing_whitespace  \
# 0  [True, True, True, True, False, False, True, F...
# 1  [True, False, False, True, True, False, False,...
# 2  [True, False, False, True, True, False, False,...
# ...

# %%
train_df.shape
# Out:
# (6807, 5)

# %%
external1.head()
# Out:
#      document                                          full_text  \
# 0  dtduupvzgt  Tiburce Evans, https://www.instagram.com/tibur...
# 1  uejmzisyyh  Rose-Mai Rodriguez | PIN # 3814374\n501 Andrea...
# 2  jzevfvijlw  Lina Wingate; 095 Terry Via\nTerrymouth, MT 24...
# 3  jqldfongxi  Lally Scales | Pin # 74,7,9,0, 658-527-2399; l...
# 4  qzgtouvmtu  Li Warfield-Fontana; 001-528-777-2370x08989, p...
#
#                                               tokens  \
# 0  [Tiburce, Evans, ,, https://www.instagram.com/...
# 1  [Rose, -, Mai, Rodriguez, |, PIN, #, 3814374, ...
# 2  [Lina, Wingate, ;, 095, Terry, Via, \n, Terrym...
# 3  [Lally, Scales, |, Pin, #, 74,7,9,0, ,, 658, -...
# 4  [Li, Warfield, -, Fontana, ;, 001, -, 528, -, ...
#
#                                               labels  \
# 0  [B-NAME_STUDENT, I-NAME_STUDENT, O, B-URL_PERS...
# 1  [B-NAME_STUDENT, I-NAME_STUDENT, I-NAME_STUDEN...
# 2  [B-NAME_STUDENT, I-NAME_STUDENT, O, B-STREET_A...
# ...

# %%
external2.head()
# Out:
#                            document  \
# 0  2cd5fb9799fe06349528c33423a0f595
# 1  3cb7ffeb0ef2f45672e53c38b29d610c
# 2  c172f453e4643ae9c9bc9d8426128217
# 3  b9edf42553f58bbffa457381a3799770
# 4  232dd2bd7be9d3a3ea93cab6e17fcbfa
#
#                                            full_text  \
# 0  Storytelling Challenge: Crafting Compelling Na...
# 1  Storytelling Challenge: The Power of Narrative...
# 2  Storytelling Challenge: The Power of Narrative...
# 3  Storytelling Challenge: Crafting Compelling Na...
# 4  Storytelling Challenge: The Power of Narrative...
#
#                                               tokens  \
# 0  [Storytelling, Challenge, :, Crafting, Compell...
# 1  [Storytelling, Challenge, :, The, Power, of, N...
# 2  [Storytelling, Challenge, :, The, Power, of, N...
# 3  [Storytelling, Challenge, :, Crafting, Compell...
# 4  [Storytelling, Challenge, :, The, Power, of, N...
#
#                                  trailing_whitespace  \
# ...

# %%
syn_df.head()
# Out:
#                                                ESSAY  \
# 0  The digital age has blurred the lines between ...
# 1  The digital age has irrevocably woven itself i...
# 2  The question of identity in the digital age is...
# 3  The flickering fluorescent lights of the unive...
# 4  ## The Unexpected Detour: Finding Community in...
#
#                                               tokens  \
# 0  ['The', 'digital', 'age', 'has', 'blurred', 't...
# 1  ['The', 'digital', 'age', 'has', 'irrevocably'...
# 2  ['The', 'question', 'of', 'identity', 'in', 't...
# 3  ['The', 'flickering', 'fluorescent', 'lights',...
# 4  ['The', 'Unexpected', 'Detour', 'Finding', 'Co...
#
#                                  trailing_whitespace  \
# 0  False,False,False,False,False,False,False,Fals...
# 1  False,False,False,False,False,False,False,Fals...
# 2  False,False,False,False,False,False,False,Fals...
# 3  False,False,False,False,False,False,False,Fals...
# ...

# %%
# Assuming you have a pandas DataFrame named df that contains the column 'ESSAY'

syn_df.rename(columns={'ESSAY': 'full_text'}, inplace=True)

# %%
syn_df.head()
# Out:
#                                            full_text  \
# 0  The digital age has blurred the lines between ...
# 1  The digital age has irrevocably woven itself i...
# 2  The question of identity in the digital age is...
# 3  The flickering fluorescent lights of the unive...
# 4  ## The Unexpected Detour: Finding Community in...
#
#                                               tokens  \
# 0  ['The', 'digital', 'age', 'has', 'blurred', 't...
# 1  ['The', 'digital', 'age', 'has', 'irrevocably'...
# 2  ['The', 'question', 'of', 'identity', 'in', 't...
# 3  ['The', 'flickering', 'fluorescent', 'lights',...
# 4  ['The', 'Unexpected', 'Detour', 'Finding', 'Co...
#
#                                  trailing_whitespace  \
# 0  False,False,False,False,False,False,False,Fals...
# 1  False,False,False,False,False,False,False,Fals...
# 2  False,False,False,False,False,False,False,Fals...
# 3  False,False,False,False,False,False,False,Fals...
# ...

# %%
# I want to row bined the syn_df and train_df. How can I do that?

row_binded_df = pd.concat([syn_df, train_df, external1, external2], axis=0)

# %%
row_binded_df.head()
# Out:
#                                            full_text  \
# 0  The digital age has blurred the lines between ...
# 1  The digital age has irrevocably woven itself i...
# 2  The question of identity in the digital age is...
# 3  The flickering fluorescent lights of the unive...
# 4  ## The Unexpected Detour: Finding Community in...
#
#                                               tokens  \
# 0  ['The', 'digital', 'age', 'has', 'blurred', 't...
# 1  ['The', 'digital', 'age', 'has', 'irrevocably'...
# 2  ['The', 'question', 'of', 'identity', 'in', 't...
# 3  ['The', 'flickering', 'fluorescent', 'lights',...
# 4  ['The', 'Unexpected', 'Detour', 'Finding', 'Co...
#
#                                  trailing_whitespace  \
# 0  False,False,False,False,False,False,False,Fals...
# 1  False,False,False,False,False,False,False,Fals...
# 2  False,False,False,False,False,False,False,Fals...
# 3  False,False,False,False,False,False,False,Fals...
# ...

# %%
# After modification

row_binded_df = row_binded_df[['full_text', 'tokens', 'trailing_whitespace', 'labels']]

# %%
row_binded_df
# Out:
#                                               full_text  \
# 0     The digital age has blurred the lines between ...
# 1     The digital age has irrevocably woven itself i...
# 2     The question of identity in the digital age is...
# 3     The flickering fluorescent lights of the unive...
# 4     ## The Unexpected Detour: Finding Community in...
# ...                                                 ...
# 2687  Mind Mapping Tool for Idea Generation and Prob...
# 2688  Mind Mapping Tool for Idea Generation and Prob...
# 2689  Mind Mapping Tools for Idea Generation and Pro...
# 2690  Mind Mapping Tool for Idea Generation and Prob...
# 2691  Mind Mapping Tool for Idea Generation and Prob...
#
#                                                  tokens  \
# 0     ['The', 'digital', 'age', 'has', 'blurred', 't...
# 1     ['The', 'digital', 'age', 'has', 'irrevocably'...
# 2     ['The', 'question', 'of', 'identity', 'in', 't...
# 3     ['The', 'flickering', 'fluorescent', 'lights',...
# ...

# %%
# output directory 
import os
output_path = complete_data

# CSV

row_binded_df.to_csv(output_path, index=False)
